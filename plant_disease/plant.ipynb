# %%
import numpy as np
import pandas as pd
import os
import os
import torch
import torchvision.transforms as transforms
from torchvision.datasets import ImageFolder
from PIL import Image
import random
# for dirname, _, filenames in os.walk('/kaggle/input'):
#     for filename in filenames:
#         print(os.path.join(dirname, filename))

# %%
# !unzip /content/drive/MyDrive/raw.zip -d raw
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/4deac08b-8a7b-4929-ade6-17084091a7ba___YLCV_GCREC 2591_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/4deca691-c66c-435a-885f-9e7340879695___YLCV_GCREC 5541_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/4df08bed-1278-48e5-b412-72ee13f3cc37___YLCV_NREC 2356_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/4e31c6ed-e785-4c65-8694-89ef2b4a1b0d___UF.GRC_YLCV_Lab 02507_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/4e63af06-ec7c-4888-9a2d-86cd6278d4b4___UF.GRC_YLCV_Lab 09511_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/4e6c618f-81e3-47cf-b4b4-cbe2098621ce___YLCV_NREC 2587_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/4f674d39-511e-4d69-93e7-3bce11b27e45___YLCV_GCREC 5113_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/4f7c7918-df06-4a88-a48d-f06609e7b138___YLCV_NREC 2626_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/4f92269c-6182-44f7-9352-b318bcd917bd___YLCV_GCREC 2179_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/4f9e72d6-8125-4b94-9def-169c2c311721___YLCV_GCREC 2515_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/4fb6720b-508c-49cc-b3e0-81656128bf59___YLCV_GCREC 1999_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/4fe2b056-c257-4931-a01d-7bfeb615859a___YLCV_GCREC 2487_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/506e6868-cab4-4109-8b63-40d7350c4e79___YLCV_NREC 0307_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/50b312da-286f-4651-afb1-bc4cd63e6afb___YLCV_GCREC 2300_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/50c3799c-1ee9-4c5f-ba71-0b7cc82a9b9f___YLCV_GCREC 2050_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/5133c1b3-8a52-44a9-9c34-b9c4ea54b301___YLCV_GCREC 5347_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/513e8592-6fca-4084-bd75-cc1b52bf45dd___UF.GRC_YLCV_Lab 02461_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/516427b3-ff59-4022-8bd5-603505013e1b___YLCV_NREC 0290_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/51bd05fe-a50b-4bc1-aa3d-096a5621531d___UF.GRC_YLCV_Lab 01719_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/51cb265d-d883-4cde-94cb-1575a87e4b83___UF.GRC_YLCV_Lab 02663_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/51d871e3-a079-4dd7-a3c6-0991ddb9b4fd___UF.GRC_YLCV_Lab 08558_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/51f629a9-de2f-4304-8241-1b3e5333d0fb___YLCV_GCREC 2853_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/51f7c310-dcb6-49a3-851d-c4d281ccb57d___YLCV_NREC 0159_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/5203ecbd-f0d7-46fd-94b7-a84eb963290d___YLCV_NREC 1994_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/52194a42-49b2-4711-84ff-ec707c820a94___YLCV_NREC 2981_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/52427a54-ed33-4e61-a367-834552dc5fcc___YLCV_GCREC 1983_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/5260fe03-de78-449d-8c3a-82534bba19a8___YLCV_NREC 2348_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/526b3cf6-007f-483a-93e7-c2722dee99a2___UF.GRC_YLCV_Lab 02124_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/5296d967-8fb0-48f3-b8c2-2d95ab89065a___YLCV_GCREC 2504_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/52b2ab4a-c69a-4c36-be2f-600f40b2849b___UF.GRC_YLCV_Lab 02411_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/52e8acae-b1a9-4107-aef9-c021fd8a1501___UF.GRC_YLCV_Lab 01364_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/52f1ffbd-5244-4102-aaea-5e1f176f358d___UF.GRC_YLCV_Lab 03306_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/53251828-7d15-4c0d-8f67-795b69326594___YLCV_GCREC 2270_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/536e6625-3142-40df-a1cf-dd29a0f501db___YLCV_NREC 0202_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/53788a56-dfa1-4761-a4d7-0ae813a0b18b___YLCV_NREC 0118_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/53b914ea-4c7e-4e35-944c-2aac000557db___YLCV_GCREC 2147_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/5420af41-c0ca-40b9-bcb0-03b3b63abed4___UF.GRC_YLCV_Lab 02554_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/54447643-06bc-4315-be51-0e8126fae338___UF.GRC_YLCV_Lab 02262_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/547afc41-636c-46ed-bac0-189da3d7caa7___YLCV_GCREC 2008_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/552e4223-9503-49d7-b22c-33d1dac5ee78___UF.GRC_YLCV_Lab 02460_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/55e6db49-3ee0-48b5-b160-972044667ccc___YLCV_GCREC 2819_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/5603219d-7494-4cf2-98f2-60d7fd5e62a4___YLCV_NREC 2642_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/56395f6d-229b-4c90-b8c6-b0a7fcde947d___UF.GRC_YLCV_Lab 01510_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/56405635-5a4f-431f-a6ac-f279b8478a89___UF.GRC_YLCV_Lab 02221_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/56421a33-a42d-4c4f-8f68-03f458deb53f___YLCV_NREC 2072_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/56ba0dc9-340e-44f8-aa1a-947639c33ffb___UF.GRC_YLCV_Lab 03285_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/5774baf6-25c1-4c89-b9c4-f2ccee5eb4bd___YLCV_GCREC 1992_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/5779e4af-7f3c-4f03-9cf2-bc2f77ae6d25___UF.GRC_YLCV_Lab 08547_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/5785e621-7c0e-49cd-ac81-4a7a8612f678___YLCV_GCREC 5183_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/5790959b-506b-42f6-b281-93479fbf07c2___UF.GRC_YLCV_Lab 09364_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/579d915a-9118-4c03-8362-e731f182dc23___UF.GRC_YLCV_Lab 08566_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/57b2a2ca-be23-4974-bfec-b0778ac01bb9___YLCV_GCREC 2358_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/57dd8748-5491-4606-8d05-77f701075df4___UF.GRC_YLCV_Lab 09446_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/57f23e68-d6cf-4ba5-8659-7c074253b1ae___UF.GRC_YLCV_Lab 01960_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/580d41da-dea3-4249-bb02-ad990ec3cdc5___YLCV_NREC 2801_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/582daccf-cd4d-4f37-bc17-7cf430a6aaba___YLCV_GCREC 2679_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/5857b6f9-fe50-4850-927b-26940a8255ff___YLCV_GCREC 2087_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/58baecd6-1b55-47dc-bd4f-d27116cf222e___YLCV_GCREC 5302_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/59375be6-ea91-4194-8dbf-9a5433690f89___UF.GRC_YLCV_Lab 02061_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/59571b59-e618-47fe-8294-fed42e841cc9___UF.GRC_YLCV_Lab 09359_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/5a19bbfe-909b-4d40-b92b-19534a9e9c9d___YLCV_GCREC 2697_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/5a1ad8fc-0125-46fd-bd87-26b2294633c3___UF.GRC_YLCV_Lab 08528_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/5aa622eb-9e39-43c4-ae2e-01172b9a09a7___YLCV_GCREC 5114_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/5aa968e0-88c7-41e2-b602-df1a85e9c531___YLCV_GCREC 2502_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/5abf1f15-6800-423c-a057-14027e12cace___UF.GRC_YLCV_Lab 02720_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/5af8e38e-7ee5-4b46-8e02-a2cf4ede14a7___YLCV_NREC 2228_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/5b002ec9-56a4-4e6a-bdf5-0cc2ea23e4c7___UF.GRC_YLCV_Lab 02728_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/5b0da93b-d51d-4e69-a124-a2f967aa67bd___UF.GRC_YLCV_Lab 02309_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/5b1b29b2-c660-4929-a442-b263df503d48___YLCV_NREC 2278_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/5b3e9035-71e9-4113-b6eb-fff0ed904099___UF.GRC_YLCV_Lab 02514_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/5b7a04ef-85c3-441c-9e73-94c4d2b6383d___UF.GRC_YLCV_Lab 03063_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/5b8b8ba2-43ea-4e86-a75c-883fe4b1f70f___YLCV_NREC 2010_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/5bc7b859-49ae-42e1-9d24-7bff99566df4___UF.GRC_YLCV_Lab 03390_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/5bf51eeb-ffe7-48e2-9799-a27735dde9e4___YLCV_GCREC 5344_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/5c7f3f68-f289-40cd-a434-31b213ca9083___YLCV_NREC 2214_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/5d40d3db-1277-4136-9276-229450f81b5b___YLCV_NREC 2588_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/5e70b8f4-26db-4ac4-a23a-dac4fd0be93a___YLCV_GCREC 5401_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/5f2aaa59-4a61-4dde-bd0a-cc5d414d8d1a___UF.GRC_YLCV_Lab 02611_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/5f4c7b5e-0f27-402e-9226-9a76d5058528___UF.GRC_YLCV_Lab 01481_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/5fa4b5e9-4755-4b9b-98b5-4912fb21e820___YLCV_GCREC 2797_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/6075fa49-0f9d-4966-8ab6-69bcf429783b___UF.GRC_YLCV_Lab 01613_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/60a19659-7e7d-4163-960b-add05432aea2___UF.GRC_YLCV_Lab 02432_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/60b08403-46e2-498d-8aff-548324455f61___YLCV_NREC 2464_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/612c246b-6f3b-4b5d-a13b-a8c028d86873___YLCV_NREC 2836_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/6159812d-5f51-4c3e-b3b6-cddf626893a3___UF.GRC_YLCV_Lab 02640_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/615a35a3-9a43-4325-8411-6548b893df15___YLCV_GCREC 2851_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/616ab037-f8ad-4a57-be0e-89c4f97f449c___UF.GRC_YLCV_Lab 02588_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/616f702b-a019-4292-9c72-af6ff050b99b___UF.GRC_YLCV_Lab 03311_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/62541cc6-4e4e-4316-af45-159254d4510d___YLCV_NREC 2602_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/6296d676-cbdf-4481-9188-d628c870713e___UF.GRC_YLCV_Lab 03246_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/62ae85b3-ed7b-476b-8e83-0c40bcac46ac___YLCV_GCREC 2154_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/62b6281e-3bc1-4677-9b4f-3e59396641c8___YLCV_NREC 2566_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/62eb4afa-df30-48f1-a779-38b6f3a3c315___YLCV_GCREC 2013_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/6343c9b3-a054-4d73-912d-97c7f9a9ee83___UF.GRC_YLCV_Lab 02018_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/63850dfe-2c79-4728-8557-b1eb242e16f1___YLCV_GCREC 2298_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/64598994-2818-4d04-93b8-351980d5a7c5___YLCV_GCREC 2458_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/657a028b-f6bf-4a6b-9e97-87e2ae27ee67___YLCV_NREC 2155_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/65b0d07c-0e72-4ce3-8800-591136f2a78b___YLCV_NREC 2827_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/66473ce4-e4f2-45dc-aa35-a79f481ba0b3___UF.GRC_YLCV_Lab 01555_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/6652e757-b4c5-452f-a36c-dc14a7a6920e___UF.GRC_YLCV_Lab 02813_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/66bee1f0-5737-444a-9698-1c9c0217bbb5___YLCV_NREC 2794_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/6701ac79-58d6-4e12-905a-2cf942ff6b51___YLCV_GCREC 5424_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/67727242-9c27-4ab5-8b7b-2ae2a33080c8___YLCV_NREC 2750_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/67d2fd78-d897-4e0c-831c-e8d373829a9f___YLCV_GCREC 2198_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/67e78746-5c79-43b8-a73f-3ba6cb0b91f9___UF.GRC_YLCV_Lab 02823_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/685faff6-cb72-47fc-9df7-a881165fe3e7___YLCV_NREC 0069_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/6978a503-bdb6-4faa-a884-98ca3c886957___YLCV_NREC 2662_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/69ff2614-f5a7-484c-973e-437a9eb3b2fc___UF.GRC_YLCV_Lab 01365_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/6a40c2cc-0d3c-409d-9a7d-85ebe1cadd69___UF.GRC_YLCV_Lab 03048_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/6a684d3a-4ae1-4f86-8f0f-3755adf2afbf___YLCV_GCREC 2529_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/6a77132a-cbbd-4465-8cff-56bdcf55dd8d___YLCV_NREC 2173_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/6a928387-47c0-4d6e-9fed-ca76de4355c7___UF.GRC_YLCV_Lab 02982_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/6ace723b-0967-4a62-80ca-222d240123f4___UF.GRC_YLCV_Lab 02830_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/6afa75f0-ed92-49ed-8e3e-e222f212e5ad___UF.GRC_YLCV_Lab 01591_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/6b761df1-9293-433b-b771-77c7e9a8aa74___UF.GRC_YLCV_Lab 02050_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/6b9b1888-d553-4044-9b52-96bd2cccda0d___UF.GRC_YLCV_Lab 01540_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/6bd38152-a092-419b-974e-1a7231794f4e___YLCV_NREC 2131_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/6c4cb190-f0e4-4e02-a7cc-c42ecab50e56___YLCV_NREC 2948_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/6c6c2702-7036-4d75-99a3-7da8df966606___UF.GRC_YLCV_Lab 02390_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/6c6fcd54-9d2b-49f5-9337-1f0d86e60fd1___UF.GRC_YLCV_Lab 03399_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/6cddeaab-6f47-475a-886f-c8947d314788___UF.GRC_YLCV_Lab 02714_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/6d9a72c4-5c43-4889-8faf-99fdaeb269b2___UF.GRC_YLCV_Lab 03312_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/6db961db-79dd-4325-93dd-07cfa78b7a2b___YLCV_GCREC 2250_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/6e1df9ed-44b3-4744-a060-c47a236565e3___UF.GRC_YLCV_Lab 02203_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/6e1ea630-4b8f-4305-84a2-b940698329bf___UF.GRC_YLCV_Lab 09495_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/6e965ff5-c45a-474c-995f-85832f916e64___YLCV_NREC 2530_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/6edbefd9-9755-456a-8ba9-dd7a9c467cc3___YLCV_GCREC 2533_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/6f229bf2-8e59-48ee-a175-7b7ca2768c58___UF.GRC_YLCV_Lab 02690_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/6fb75150-5ad0-494c-961c-4a32c95d6acd___UF.GRC_YLCV_Lab 03259_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/6fd9e3a5-82cc-450d-beaf-10dcc024c64d___YLCV_NREC 2047_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/6ff8f2bf-6ba0-417b-8f85-736d191eca9b___YLCV_GCREC 2835_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/700b2b34-d31d-436f-9a7c-59491dbe908e___UF.GRC_YLCV_Lab 03314_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/7086de63-abfe-40fc-aa74-adcfda695312___YLCV_GCREC 2172_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/709a8acc-35e1-450b-844c-46bbe6cab281___YLCV_NREC 0252_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/711bb3ff-a4d2-4f24-b8f8-6b5e3cbe6cbd___YLCV_NREC 2822_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/711f8839-09f1-4ca6-8681-57bba5be4b75___UF.GRC_YLCV_Lab 02646_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/715c0428-2bd8-4c35-b39d-f90e1358544b___YLCV_GCREC 2437_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/7162cc3f-21ca-4196-b967-10376a4940d9___YLCV_GCREC 2844_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/71a5615a-5fcf-4361-8efc-f4933a4f2900___YLCV_NREC 0143_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/72438b76-1114-43ae-a402-c2a84763d776___YLCV_GCREC 2301_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/72479a2c-c9a2-4813-b330-44499a10db1f___UF.GRC_YLCV_Lab 02496_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/7257f560-6655-4aa2-95cb-42d6c98c1229___YLCV_NREC 0236_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/7267fbca-dd92-4dd2-a434-f608e90d9674___YLCV_NREC 2935_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/73734f51-843b-4355-b16d-be9a22f65ab5___YLCV_GCREC 2256_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/737b87f3-b7df-49e2-8434-4e1cf0756a21___UF.GRC_YLCV_Lab 08491_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/73ac94a4-7ca4-4716-bdc9-f27355d3b5ea___YLCV_NREC 0105_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/74241a47-7b5c-4e56-b63a-3cb954ab5d8d___UF.GRC_YLCV_Lab 02580_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/744f3cfe-d7bc-4e16-9ed1-cd65a8a88846___UF.GRC_YLCV_Lab 02598_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/7475a28c-f789-49d9-8289-17a5dc97717b___YLCV_GCREC 2895_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/74dafee0-94a5-4e07-9b04-c85f4cd9928a___YLCV_NREC 2243_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/7502f8cf-3966-4e1b-bbb5-9a2db01ced48___UF.GRC_YLCV_Lab 01922_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/75033ceb-b250-4af7-b54f-0f1b170d8aa2___YLCV_NREC 2928_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/75752767-df17-4f29-b45a-8b1034ffe257___UF.GRC_YLCV_Lab 03155_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/75b2e6cc-9a7d-42b8-b6d8-73532f0503bb___YLCV_NREC 2366_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/75dd0ad6-c0c5-457a-80e4-e967b7330350___YLCV_NREC 0178_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/75e3673f-9532-4b79-becb-855c353c2bd1___YLCV_GCREC 2555_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/75fbe8d1-9d11-4039-9973-ba2599641426___UF.GRC_YLCV_Lab 02548_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/75ffc4e4-e18f-47ee-8224-6d2aa808d2ee___UF.GRC_YLCV_Lab 01537_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/7659846e-0003-42bc-ba6f-d553ea1971b3___UF.GRC_YLCV_Lab 01644_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/76bc3125-07e1-40f7-9a88-e3fa2153569b___UF.GRC_YLCV_Lab 03061_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/7774d595-bce2-4ec0-8a10-85ba887029fa___YLCV_NREC 2390_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/77eaf955-9ae7-4dc7-8fca-5746faa341d2___YLCV_GCREC 5196_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/780812ad-50f2-41b2-96ca-d3af691e970c___YLCV_NREC 0233_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/785b8aa5-f6e9-4e47-8b65-28d32572912e___UF.GRC_YLCV_Lab 02386_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/7888a778-5d18-4abc-a5d0-ac621b42406f___UF.GRC_YLCV_Lab 09360_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/78fd411e-6aff-42a5-8797-a56b80346ccb___UF.GRC_YLCV_Lab 02539_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/79032fad-7cb4-47e8-8b5d-c15f61d3f66b___YLCV_GCREC 2231_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/7935cc47-b977-4472-ad3f-41eeb219dd32___UF.GRC_YLCV_Lab 01863_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/796957f9-4d32-463a-b8b5-adceaa3e8006___YLCV_GCREC 2253_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/7997a8cd-bc11-411a-8992-2842a65b6c62___YLCV_GCREC 5232_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/7a0706ca-a443-4491-bb4b-41d926af55b0___YLCV_NREC 2143_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/7a248c72-1dae-4532-b083-b0bee802cb4b___UF.GRC_YLCV_Lab 01722_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/7a2cb83d-4fcc-47bd-a893-ad284db06267___YLCV_NREC 2816_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/7added13-bd04-4fe3-b1a8-33d3446e70da___YLCV_GCREC 2889_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/7ae4111b-ccb5-4367-8262-72eca8f50f23___YLCV_GCREC 2500_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/7aebaae8-ddd3-42ad-930a-0366245ffa04___YLCV_GCREC 5507_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/7b135de6-cf67-450c-86c4-59f99edb7c8d___UF.GRC_YLCV_Lab 03395_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/7b1d24af-cc7c-4883-afcf-6f0d46254281___YLCV_GCREC 5469_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/7b29fda8-5d5a-4158-827d-99417978fbcc___YLCV_GCREC 2135_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/7b2f5b12-b094-4672-bc3c-f7d758049da1___YLCV_GCREC 2858_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/7b49148d-a987-4e7c-b152-e7bf1dc32075___UF.GRC_YLCV_Lab 08449_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/7bc84e32-7cd8-466c-9000-d32ee7e75e9c___UF.GRC_YLCV_Lab 02674_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/7bd36299-ae5f-40ac-81b1-99adefbc6950___YLCV_GCREC 5488_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/7bff3fb7-788d-414c-bf0e-92a5ce4a4757___UF.GRC_YLCV_Lab 02064_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/7c215f7a-4aaf-4461-a727-7e4777daa562___UF.GRC_YLCV_Lab 01624_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/7c21fc98-1815-4b72-a6ac-378ad446a3e7___UF.GRC_YLCV_Lab 03000_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/7c253e30-e121-4c44-be3a-53f121104f77___YLCV_NREC 2818_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/7c34e58a-5d8a-4da8-b3c0-843a1bf64584___YLCV_GCREC 1943_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/7c3b7cf9-577b-44d6-841f-1d3a5f224d4e___UF.GRC_YLCV_Lab 03316_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/7c5b5998-668f-4f9e-97cf-978583a24841___YLCV_GCREC 2276_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/7c6b3ee3-33cf-4a2c-a245-497b88d6d9b9___UF.GRC_YLCV_Lab 09607_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/7c74d6cc-d114-4031-a675-2c6bb6ff7b48___UF.GRC_YLCV_Lab 09612_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/7c75b36b-61fe-4c5a-b371-8bb7bf128334___UF.GRC_YLCV_Lab 09471_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/7d33e936-13b3-4df1-9364-68dc42179683___YLCV_GCREC 2056_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/7dafbb8c-1edc-4dd1-b593-614b4bcf220d___UF.GRC_YLCV_Lab 02643_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/7dea7207-b67a-40ee-b79c-428a5c038e86___UF.GRC_YLCV_Lab 02340_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/7e2db57b-c9b3-456d-9187-de6ada3287f4___YLCV_GCREC 2077_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/7e2dddcf-d20a-4bd9-a79d-69c12872c24d___YLCV_GCREC 2626_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/7e87c1d5-83ae-4adc-959d-b744566aecc3___YLCV_GCREC 2132_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/7e9191c4-0421-4171-8e46-bb076ab6c692___YLCV_NREC 2494_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/7ea7bd33-f6ac-4993-b5b4-1d743c3bc5cc___YLCV_GCREC 5335_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/7f54ac2c-da47-4b56-9dc3-ae002c887d9e___UF.GRC_YLCV_Lab 01964_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/7f6ed384-0237-45d8-bc6b-edfe9e881785___UF.GRC_YLCV_Lab 01472_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/7fcaa4d4-8ba0-4c87-84fe-7e06a45f0326___UF.GRC_YLCV_Lab 09614_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/8017d3a2-d1c8-4332-80be-e193b9dd0357___UF.GRC_YLCV_Lab 02103_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/801e82bd-bffa-47a5-b90d-8b7b3512a4b2___UF.GRC_YLCV_Lab 03304_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/80274194-0aa0-48a1-add7-48c8d728300c___YLCV_NREC 0144_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/803627e6-13fe-4e3e-8890-cd3c4bc9029c___UF.GRC_YLCV_Lab 02013_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/8059bfc1-a2e0-4684-a4f0-c69c676fff34___UF.GRC_YLCV_Lab 02796_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/80d440bf-1ce0-42f2-a3b4-8c09f281d044___UF.GRC_YLCV_Lab 03045_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/80dd36a8-5ce2-47eb-9d19-508ce9d72efe___YLCV_NREC 2447_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/81018ae7-ef98-4b5e-b957-77f11caaf1e1___YLCV_GCREC 2321_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/810799d4-d5a0-4fc9-908c-a27e3a617e14___YLCV_NREC 2048_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/81430658-7687-4bdc-9b1c-f2563606d304___YLCV_NREC 0097_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/81a7b0d8-0e23-474e-8e3a-1d133a52de97___YLCV_GCREC 2575_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/81c2cdcc-9254-45b3-8d53-6a928179a925___YLCV_NREC 2991_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/821fd577-b818-4d94-ac0c-fc7d9e728eb2___UF.GRC_YLCV_Lab 02959_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/825d8f5e-ade2-44f8-9303-3073e8b7fe5f___YLCV_NREC 2698_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/83afa77a-0593-41f4-a395-63d59df33d5d___UF.GRC_YLCV_Lab 01606_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/83bd57f8-9061-4b1d-ac71-b426f16c7be6___UF.GRC_YLCV_Lab 02870_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/83f2a041-2db2-4240-89ae-d0c8a7b56b84___YLCV_NREC 2205_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/84244edf-a195-4e38-9add-99f7a28a17cb___UF.GRC_YLCV_Lab 01972_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/843abaaf-e144-4200-90ea-4fe6ee81e185___UF.GRC_YLCV_Lab 09608_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/844653ae-8a16-434b-82c9-e4ad7dadb867___YLCV_GCREC 2816_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/8486dc84-3cec-4289-8c8f-73e651c564e9___YLCV_NREC 2051_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/852da2af-2291-40f6-baf5-92211f5e876a___YLCV_GCREC 2041_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/8532dd5f-896a-4b03-9ac6-f7887bf093dc___YLCV_NREC 2245_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/863ec65a-13fc-42a9-9e03-4a3609e746f8___UF.GRC_YLCV_Lab 01950_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/8642e4ee-a903-4bfd-a774-f3d42b871dd0___YLCV_GCREC 5384_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/86665379-33ec-44c1-96c2-8de18bba4ba9___UF.GRC_YLCV_Lab 09367_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/868fd1c3-faf9-40d2-b9a3-16e4b2f11be9___YLCV_GCREC 5157_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/86ac31fc-a8e8-4935-8276-e80d4946d77a___YLCV_GCREC 2214_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/86b990c2-8a73-4c59-82e7-e89c72e1c73c___YLCV_GCREC 2663_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/87226c34-d7bf-4767-afdc-8a56cf45586a___YLCV_NREC 2380_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/87cea921-e038-4cd2-a14e-31a45ae2560d___UF.GRC_YLCV_Lab 03298_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/88228c71-4e2e-4e58-8f57-d6c3f0dc1bb5___YLCV_GCREC 5410_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/887aa630-362e-431a-83be-8abac44a76e9___UF.GRC_YLCV_Lab 03099_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/892451b0-68b4-4787-9856-e07c933dbeb1___YLCV_GCREC 2359_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/8943c380-18db-4f4f-ae02-5603e5cda202___YLCV_GCREC 5249_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/898afc66-c48e-4c45-9859-98fa177b2dd0___UF.GRC_YLCV_Lab 09402_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/89fe420f-3f9a-4b1a-b19d-f866dfd0800a___UF.GRC_YLCV_Lab 01955_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/8abed001-72ef-4918-ba5e-3487fabb240a___UF.GRC_YLCV_Lab 02478_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/8aeacb4f-d041-42b1-8c66-064bb11f1f2f___YLCV_GCREC 5389_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/8b2d1dc6-858b-452e-99a2-6ffbbc211051___UF.GRC_YLCV_Lab 09391_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/8b3b339e-d9a1-49cd-8ee1-1a609811e0c4___YLCV_GCREC 5361_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/8b63fb5c-6731-451e-8151-639482fb81d8___UF.GRC_YLCV_Lab 01612_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/8ba52e1d-35f7-498a-987d-9dea899538bf___YLCV_GCREC 2648_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/8bc6637b-8f4e-49c3-9f82-4704c25d2188___UF.GRC_YLCV_Lab 03196_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/8bf1c6d4-b64e-4a94-a4de-c177fff111ce___UF.GRC_YLCV_Lab 09545_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/8bfac020-c591-4fbb-aa1d-f6e2499ee6a2___UF.GRC_YLCV_Lab 02903_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/8c179530-6991-422e-a933-da6d727aac82___UF.GRC_YLCV_Lab 01466_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/8c34b76a-aa97-4619-8140-c8fd200cd429___YLCV_NREC 2056_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/8c9bed1b-3a4c-47d0-bd84-1e3ce8d09344___UF.GRC_YLCV_Lab 03065_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/8cf12f2f-30db-4019-9efd-6eabed9713f7___YLCV_NREC 2280_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/8d3f9b57-d972-4e7c-a238-147e00dcb4e1___YLCV_NREC 2062_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/8d6df373-91b8-4ae8-b358-e9d57a6f3d54___UF.GRC_YLCV_Lab 02828_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/8d7689ca-7734-4c78-a006-659c8cd9d1df___UF.GRC_YLCV_Lab 01532_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/8d8db0d2-a2a8-4bd6-ac05-7a158dea14a7___YLCV_NREC 0185_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/8e394d62-3c7b-4116-8f16-36d1930d4320___UF.GRC_YLCV_Lab 01871_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/8e48ed0b-90d5-4d74-bea6-697c4146535e___UF.GRC_YLCV_Lab 08505_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/8f1dc4b2-220e-4afd-a559-48a2f142007c___YLCV_NREC 2298_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/8f20c57c-4c46-44ee-80f4-c67f882e46a9___UF.GRC_YLCV_Lab 02180_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/8f3ed21d-2ba4-42e4-b8d6-c83ee1fdf1fc___UF.GRC_YLCV_Lab 02348_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/8f7f2459-7493-416d-af69-200d1eeb07fa___YLCV_NREC 2082_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/8f8f5b03-854c-4572-ac84-2893366dffef___YLCV_GCREC 2750_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/905c989e-b114-4491-927a-8a4d1cb1f47b___YLCV_GCREC 1905_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/90703f86-170c-4ef4-8fc1-8a165b2eb15e___UF.GRC_YLCV_Lab 01948_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/915bab07-9a79-4144-9e60-4e65d44c4294___YLCV_NREC 2783_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/91993f6d-d1d6-4022-899c-65ea7a83e96e___YLCV_GCREC 2901_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/91ca0680-4696-4828-8bac-8d42436f9559___YLCV_GCREC 1947_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/9218155b-9722-4cb6-8798-77e762f0cc91___UF.GRC_YLCV_Lab 03157_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/9225bddd-f4c3-4b56-82fd-3526fa3147bb___YLCV_NREC 2085_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/9283b89a-30fa-49fa-af3f-6b90daedec6a___UF.GRC_YLCV_Lab 02008_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/92993d98-9fe1-4299-98c9-c1cb1caa7a67___UF.GRC_YLCV_Lab 09346_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/92d50995-b924-4c8c-97d9-5083effeb227___UF.GRC_YLCV_Lab 09611_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/92e2fc60-5e8e-483d-85fd-ec62c11a20a7___UF.GRC_YLCV_Lab 02294_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/92f5b61b-1970-41b3-9c72-f648feadd735___UF.GRC_YLCV_Lab 08482_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/9303b8a2-2e6b-46c0-b650-4bf4016b7a2e___YLCV_GCREC 2085_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/935376fd-5756-47de-b5b0-da5e0f8283c2___UF.GRC_YLCV_Lab 08560_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/93e37751-6fc2-41fb-b0fd-9639cba54c98___UF.GRC_YLCV_Lab 01277_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/95663aad-c162-439e-b12e-9f9061b9474e___UF.GRC_YLCV_Lab 08463_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/95b2ee1b-bad2-40b9-8d17-190828ebdfde___YLCV_NREC 2283_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/966393c2-cef5-4fe7-b6e2-e6f6b7cfac0a___UF.GRC_YLCV_Lab 01569_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/96704227-fc47-4936-b22a-cea82babc0c4___UF.GRC_YLCV_Lab 02426_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/96da5e05-48ab-4461-b5ca-5d884df2c23f___YLCV_GCREC 2126_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/97319300-aa14-400c-8b8e-fdbaaefe9ce3___YLCV_GCREC 2809_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/97882b34-4f92-4a5b-a786-01dbf67b1cc0___UF.GRC_YLCV_Lab 02845_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/97ca797d-63b5-4372-8525-8873a7b92f2e___UF.GRC_YLCV_Lab 03020_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/98948e7a-782c-414a-aae4-e717f918ed03___YLCV_GCREC 2848_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/98a26c39-bf0a-44ca-9856-b855c8a96bd1___YLCV_GCREC 5273_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/9908a907-4143-4f88-b37f-5a37ef538bf0___UF.GRC_YLCV_Lab 02138_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/99c8ed6b-4e3c-479c-83c6-8dc0633aef22___UF.GRC_YLCV_Lab 08556_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/9a3d810d-3205-4e49-9e65-cd24b431c0c6___YLCV_GCREC 1902_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/9a4aeffb-a8d4-4433-a69d-30bb703d5a0f___UF.GRC_YLCV_Lab 02133_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/9a4c43d3-017b-4915-9aa6-c4e4d9cd01d6___YLCV_GCREC 5212_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/9a7182f5-7161-4177-b5dc-142444669e4e___YLCV_GCREC 2029_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/9a9a7af6-33e0-4c4d-8251-f91184e70051___YLCV_GCREC 1979_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/9aa143c8-5f40-4499-aac7-2f9525381fb4___UF.GRC_YLCV_Lab 02901_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/9ab57658-c430-4965-97e3-9d93396e2e35___YLCV_GCREC 2593_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/9b5f5c21-67da-4eb5-9625-567e22d15cbc___UF.GRC_YLCV_Lab 02254_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/9bf28103-50ef-4fdc-a06c-86b61d34e8ae___YLCV_NREC 2865_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/9bfe3055-ad97-450a-826b-9c4fa0541931___YLCV_NREC 2683_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/9c1adbe5-7451-49fc-adab-141f97949ac1___YLCV_GCREC 2650_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/9ca23fe4-e698-4cd4-ae7e-63c7777cfa65___YLCV_GCREC 2762_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/9ca57e81-652c-4abc-a2c0-45e17c776857___YLCV_NREC 2481_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/9cdbac6b-4744-408e-bc9a-4e4294530969___YLCV_GCREC 5493_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/9cfa3f33-36c3-4812-9d23-73898c39d8db___UF.GRC_YLCV_Lab 01362_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/9d6a56fc-85ac-4519-91e9-cb307410cd0c___YLCV_GCREC 2557_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/9d91ea39-a652-4c2c-8eec-2ebbfa7dbd27___UF.GRC_YLCV_Lab 01695_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/9dc7206f-8004-4ba8-8f2a-6bc69de6afa3___YLCV_NREC 0188_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/9e030168-9724-409c-b271-c7ad62afc35e___UF.GRC_YLCV_Lab 02572_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/9e962b25-a670-4e4c-bbf2-1adb5af08dfd___UF.GRC_YLCV_Lab 02648_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/9ecd884d-9394-4676-88d9-18f17f046361___YLCV_GCREC 2413_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/9ed054ae-090a-47a5-a67a-8d8b7d8fe85a___YLCV_GCREC 5458_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/9eeb9c15-3fc4-4340-8d7e-cc619b1a7a6e___UF.GRC_YLCV_Lab 01499_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/9ef634b5-dceb-4da9-a8f5-2eb5848721ce___UF.GRC_YLCV_Lab 01886_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/9f1e41b6-c547-481b-9bfe-bbb62e0ebec5___YLCV_GCREC 5431_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/9f2c7391-814f-4f42-97ce-ba97e8d0e6ea___UF.GRC_YLCV_Lab 08467_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/9f7b397a-4d7b-45ef-ae7f-09c0e433b33b___UF.GRC_YLCV_Lab 01684_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/9fbc796c-a39c-433f-9173-ff72cd4bf98a___UF.GRC_YLCV_Lab 08515_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/9ff59ba4-d70a-4803-8df6-565e85871b5c___YLCV_NREC 2028_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/a00d9d3c-93f3-4d83-a8e7-254f0a524873___UF.GRC_YLCV_Lab 03393_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/a059d5b2-7c04-486f-9a92-7fd6e9199c3a___UF.GRC_YLCV_Lab 02139_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/a08beb3c-6ec8-41f5-a8de-c2f578ce4085___YLCV_NREC 2653_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/a09fa0f1-e128-44a0-9033-ce053b4971b6___UF.GRC_YLCV_Lab 01698_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/a0af1fbb-f3f4-4081-bea3-0ab45a21b2cc___UF.GRC_YLCV_Lab 02271_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/a13f4aee-7d42-4194-92ba-48c9acedf592___UF.GRC_YLCV_Lab 02322_final_masked.jpg
# ...
#   inflating: raw/raw/segmented/Tomato___healthy/c8c7cb85-d7eb-4d60-b90e-bfe5277b79ad___GH_HL Leaf 277_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___healthy/c978eccc-99c6-45d0-879c-713167f863f4___RS_HL 9888_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___healthy/c9f92d4b-9d9c-4932-ba1b-bc290987c154___RS_HL 0350_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___healthy/ca050e4b-ec58-4b88-a1be-980e908b84d4___RS_HL 0567_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___healthy/caab6cf8-07a8-422a-84e9-3311f85d2427___RS_HL 0455_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___healthy/cb4a744a-1f1d-4cb1-b2a4-f1e1a12426ca___RS_HL 9970_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___healthy/cb602835-7f6d-4926-80b4-77fe22f7ff66___GH_HL Leaf 226_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___healthy/cbd86fc5-7f88-4984-a1ed-445de8b76573___GH_HL Leaf 354.1_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___healthy/cd8d1ae6-2c8e-43ac-8314-77d88e1153c7___GH_HL Leaf 365_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___healthy/cdf10741-0ed4-4a27-a2e9-8970e4426730___RS_HL 0356_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___healthy/cdfe9df9-c3de-4660-8543-13911f281e47___RS_HL 0496_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___healthy/ce081d63-8710-460f-9f20-cc67ef62fa37___RS_HL 9685_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___healthy/ce9a5c21-e77d-4db4-baa3-d03c24e360b0___GH_HL Leaf 281_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___healthy/ce9cef60-51af-4e89-bbe7-bf463d767e99___RS_HL 0614_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___healthy/cea7fe83-103c-4b51-a9d2-75ced9a7d1a2___RS_HL 0531_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___healthy/cf021ef4-2bde-4984-8604-c813cb195fe4___RS_HL 0490_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___healthy/d01d616c-7259-461f-9f3e-98fa7a3f86e1___RS_HL 9922_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___healthy/d02f79d7-34a8-4313-924b-ca75fa38b1fb___RS_HL 9655_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___healthy/d06e33fb-58bf-440f-9dbc-a1ceec9abaea___GH_HL Leaf 383_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___healthy/d074483d-5063-4bed-93f5-c0d798e9283c___RS_HL 0231_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___healthy/d0d0643e-c7f1-4cf3-8399-cfd8a73d1af3___RS_HL 9650_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___healthy/d15336df-9f16-4f8b-805f-d74f27af2735___RS_HL 9723_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___healthy/d1750517-689b-4372-a717-6b81c0dd64b0___GH_HL Leaf 262_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___healthy/d2f0f578-3b6e-433c-962a-8c81f79eab7a___RS_HL 9623_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___healthy/d382d5de-6608-4492-a1eb-e4c525f8b3e4___GH_HL Leaf 461_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___healthy/d3d3e88a-265a-4d4d-8887-b2930272d549___RS_HL 9873_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___healthy/d48fe069-a000-4242-b6cf-fb465e47615b___RS_HL 0594_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___healthy/d578b8cd-9a1c-434b-9507-17ced7dffb34___GH_HL Leaf 249_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___healthy/d5ccbb2a-258c-4963-bdd6-d7eb22f351a5___RS_HL 9946_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___healthy/d6128bab-2cc4-4005-9184-2b7303773682___RS_HL 9828_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___healthy/d676d2f7-13a7-4d79-91fc-757b5d0bde6f___RS_HL 0601_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___healthy/d6e27864-a8c9-426f-9e46-283d0eb3a7d0___RS_HL 0452_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___healthy/d76f5b4a-9205-4a14-9181-5d3add326231___GH_HL Leaf 447_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___healthy/d80d474d-1d8a-4381-8960-db93b611b5c8___GH_HL Leaf 390_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___healthy/d84b65fd-6841-435f-9c9f-2ba8afe2f62a___RS_HL 0541_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___healthy/d88b90c0-2850-425d-af82-7bfb0f6a9dd4___GH_HL Leaf 361_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___healthy/d88e3218-6639-430b-a74b-6b7353b1b964___GH_HL Leaf 377_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___healthy/d9a6af00-1c5a-4299-9bad-b922c8b5c33e___RS_HL 0546_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___healthy/da1015eb-5c8e-436d-b367-d1f98a034e44___RS_HL 0382_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___healthy/da3e3bf7-80da-479b-99f1-f86f18d8a264___GH_HL Leaf 511.1_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___healthy/daa4e664-5ec5-4349-b8de-0673cdfe374d___GH_HL Leaf 168.1_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___healthy/dad127e0-8761-47bd-8ea1-21727847a1f4___RS_HL 0416_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___healthy/dbd289fc-1399-44fe-968d-39a5a4f16679___RS_HL 0495_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___healthy/dca7fa13-14bd-4d24-abbf-1fe2e02eac7e___GH_HL Leaf 295_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___healthy/dd311971-e56c-4305-805e-a011ecebd38b___GH_HL Leaf 432_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___healthy/dd7d8e47-35f8-4c97-900b-f095694c38ed___GH_HL Leaf 313_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___healthy/de914baa-f72d-4cbf-a9fd-a60baf466e06___GH_HL Leaf 450.1_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___healthy/dea347a1-4303-48e1-8db0-997d084e6bd0___RS_HL 9724_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___healthy/debe033e-a878-46dc-8336-8bc25811df35___GH_HL Leaf 303_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___healthy/df99e31e-11ab-49be-bd51-d1fda2667c76___GH_HL Leaf 458_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___healthy/e090d873-c435-4d1b-95dd-29f5a2f22a09___GH_HL Leaf 266.1_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___healthy/e1517f9b-6bab-415b-b8f5-1f52dd544b2d___RS_HL 0203_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___healthy/e1860bf2-2656-4dba-b9de-f80932bca552___RS_HL 0398_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___healthy/e1d129fb-f5ae-41e1-b097-445d792e4beb___RS_HL 0473_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___healthy/e283f6ea-c756-47ca-ac84-57a38138b571___GH_HL Leaf 343_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___healthy/e2869c8b-aedf-4074-bb99-28e6ed2b4223___RS_HL 9673_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___healthy/e28f30cb-755a-459b-b653-96d44b3b01b5___RS_HL 9926_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___healthy/e2bd556e-fe0f-4a97-819c-83dbc4a61ac5___GH_HL Leaf 429_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___healthy/e2bde260-6fac-4259-8b88-c7378f1ea730___RS_HL 0511_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___healthy/e336eb74-a19d-4461-871e-3124c5e0d047___RS_HL 0558_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___healthy/e357a876-daff-428c-828f-7f1b6e998175___RS_HL 0593_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___healthy/e3cc41f4-f960-44b9-96cd-61e3bd184e6d___RS_HL 0138_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___healthy/e435f5af-a994-46b5-a5c8-d721dd1788f8___RS_HL 0100_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___healthy/e47d2178-aaf3-438b-bcce-2fcb6efd833b___RS_HL 9924_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___healthy/e531e3da-a55b-41a9-8700-3e163226bfb2___GH_HL Leaf 188.1_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___healthy/e59d735a-0312-46e4-943a-2262ea2cd502___RS_HL 0428_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___healthy/e623a5a9-edc8-4c81-ada4-68b3ebadfc7e___RS_HL 0082_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___healthy/e62eacd4-0cba-4793-8c9d-7c97031642a7___RS_HL 9700_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___healthy/e6584f1d-9338-4807-a2f2-8c0a70220c22___GH_HL Leaf 239_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___healthy/e67f9352-aae3-45f5-9b36-f0da08037d51___RS_HL 9944_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___healthy/e67fdf04-f0a3-4351-b65d-a1b7362fc032___GH_HL Leaf 304.1_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___healthy/e6d12c88-7d13-4b26-ada8-c5b34ccc77a5___RS_HL 0435_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___healthy/e6f3e3b6-8d73-4564-9e0b-771302aaa6ef___RS_HL 0626_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___healthy/e6fdaad9-b536-46c3-a819-faf414cfbf47___GH_HL Leaf 500.2_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___healthy/e7a9a772-95f5-4bd4-ad34-831c3c47c024___RS_HL 9909_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___healthy/e7ab090d-f32a-46c2-b3a2-919d76437fee___RS_HL 0207_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___healthy/e7d07408-70bb-421d-9224-df4961a01cb9___GH_HL Leaf 509.1_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___healthy/e84eced1-c0a4-451a-b5bd-482bc3eda5fa___RS_HL 0304_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___healthy/e8d0f3de-312b-4316-aca4-798a51ebd423___GH_HL Leaf 520.1_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___healthy/e91d2c30-7a45-40db-b913-6714f9b89b1c___GH_HL Leaf 348_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___healthy/e9392a5e-2fac-48c5-a23d-df3aa3f61048___GH_HL Leaf 217_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___healthy/e9f02b46-dbb7-4f41-a1dc-6fe5dfe13d23___RS_HL 9821_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___healthy/e9f45c75-db52-4a85-ab72-0b9adf1f047b___GH_HL Leaf 480.1_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___healthy/ea815fb4-7c6f-4088-94d0-59609294c65e___RS_HL 9785_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___healthy/eab401a8-c014-4a63-98d4-b6144cfc7bc9___GH_HL Leaf 289_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___healthy/eb0b95d9-4012-494c-85b6-48f7e250c958___GH_HL Leaf 404_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___healthy/ec1bfc74-550b-4478-95c0-d60c1379957a___RS_HL 9879_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___healthy/ec3bb20a-2c19-421b-a4ce-7c06f18914eb___RS_HL 0609_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___healthy/ec59e000-1ee0-4998-a68f-abbfa6f6d009___RS_HL 0226_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___healthy/ec754608-21ce-40be-abd0-46a664257065___RS_HL 0376_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___healthy/ecf64cfc-d521-48af-bb48-06edc78074c5___GH_HL Leaf 323_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___healthy/ed4e4d41-ed9d-4e62-9cc8-33fadd791847___RS_HL 0338_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___healthy/edbb09c6-f6e6-4ce4-ac38-e4fa0b96f4c0___GH_HL Leaf 251_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___healthy/edd71d50-a50f-4f36-af69-6c9df7c040af___GH_HL Leaf 484.1_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___healthy/edfbcb80-5821-4c6e-a464-79f119de35ae___RS_HL 9903_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___healthy/ee83a3b8-911e-455e-be06-20583bfb6b74___GH_HL Leaf 451_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___healthy/ef23fd72-1367-41c5-820f-c89533ad258e___GH_HL Leaf 303.1_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___healthy/efdf2bd7-ff6c-424a-9d81-dc6628278dc6___RS_HL 0065_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___healthy/efe6c986-b85c-40f1-8cb5-345acbb36b71___RS_HL 0579_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___healthy/f0037c61-001d-4b1f-b794-5b5ab49d50d5___RS_HL 0527_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___healthy/f17dd662-f947-4892-9136-56dbe0feaca2___RS_HL 0503_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___healthy/f1e20811-da4e-4f0f-b8ee-f325d90f6481___RS_HL 0084_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___healthy/f2acd891-c219-4c76-b2e7-a55c7c92e018___RS_HL 9898_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___healthy/f3bc0c64-2d60-4031-b696-66a313460663___GH_HL Leaf 517.4_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___healthy/f433b7ce-cddb-4f22-8b0f-2376789c45f1___GH_HL Leaf 337_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___healthy/f437a6f0-4c35-4d6b-8eaa-ca57f18fad53___GH_HL Leaf 229_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___healthy/f48aed97-8db4-40a5-aa39-e2c3c70fe8be___GH_HL Leaf 524.1_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___healthy/f4d64977-50b0-4967-87cf-95f282f287d4___RS_HL 0554_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___healthy/f4eb7211-c823-4d1c-bb69-a74a123a2d05___RS_HL 0112_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___healthy/f5252d99-6752-457b-b430-965d545d3b41___RS_HL 0412_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___healthy/f54a5053-dca2-4460-bd8d-27be3eb1e9b4___GH_HL Leaf 495.1_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___healthy/f60f6c8b-54f7-4002-b26d-636037912c4d___RS_HL 9956_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___healthy/f65afb75-30bc-4d44-adbd-d262ebe07ad5___GH_HL Leaf 222.1_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___healthy/f6a5a9a3-f9a6-4fad-83c3-2ce3e8618b52___RS_HL 0169_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___healthy/f7df2411-8e50-46e1-b43a-cca357bee1af___GH_HL Leaf 521.1_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___healthy/f9546cff-061d-4240-88ba-492272a92847___GH_HL Leaf 176.2_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___healthy/f96987aa-d19d-415b-a68c-73a07a47d521___RS_HL 9736_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___healthy/fb084c48-8c42-43a1-8193-191ba873bd2d___GH_HL Leaf 514.1_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___healthy/fb0f6e2b-1f21-406f-83d3-2c6236d47ca0___RS_HL 0042_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___healthy/fb123526-11fd-4d0d-96cc-3423da0b61a2___RS_HL 9756_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___healthy/fb2c7e00-39a7-4be3-b8d1-b4c42c65e20e___RS_HL 9636_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___healthy/fb73cd43-aa32-4aba-978f-034c9c809c25___RS_HL 9749_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___healthy/fc22b565-e97b-454d-8792-fd945d1badc5___RS_HL 9880_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___healthy/fccb58ad-1644-403e-851b-dd3a27c893ef___GH_HL Leaf 387.1_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___healthy/fcf52850-1cc7-4b7a-8e89-3c3ec1f4be1d___RS_HL 9766_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___healthy/fd1db002-680b-432b-9d60-68b80a4a310f___RS_HL 0049_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___healthy/fd27de23-27cd-4f09-a962-df0b26899b07___RS_HL 0039_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___healthy/fd2fa9cc-2147-40ff-9e71-0056eb7884ed___GH_HL Leaf 285_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___healthy/fd31ab37-d2af-40c8-9292-e143807ec0f2___RS_HL 0507_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___healthy/fd75c626-bda9-4388-8b29-75d40ea7c6d4___RS_HL 0041_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___healthy/fde29807-8223-4fc5-a06b-7cc93101a6d1___GH_HL Leaf 174_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___healthy/fe28e4c7-0c35-4f52-984e-0e60f33a2c6e___GH_HL Leaf 198_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___healthy/fe8f8808-2631-491e-a46b-bd2a1a4958e7___GH_HL Leaf 213.1_final_masked.jpg
#   inflating: raw/raw/segmented/Tomato___healthy/ffb39943-eabb-42cf-ad09-b17019e46d66___RS_HL 9871_final_masked.jpg

# %%
augmented_dataset_path = "/kaggle/input/thermal-dataset"
import torch
from torch.utils.data import Dataset, DataLoader
from PIL import Image
import os

class ImageDataset(Dataset):
    def __init__(self, txt_file, transform=None):
        """
        Args:
            txt_file (string): Path to the .txt file containing image paths and label IDs.
            transform (callable, optional): Optional transform to be applied on an image.
        """
        self.data = []
        with open(txt_file, 'r') as file:
            for line in file:
                image_path , label = line.strip().split("|")
                image_path = image_path.replace("/home/infinity/Documents/PlantVillage-Dataset/raw" , "/content/raw/raw")
                self.data.append((image_path, int(label)))
        self.transform = transform

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        image_path, label = self.data[idx]
        # Load image
        image = Image.open(image_path).convert('RGB')
        if self.transform:
            image = self.transform(image)

        return image, label

# %%
from torchvision import transforms
transform = transforms.Compose([
        transforms.Resize((224, 224)),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
    ])

dataset = ImageDataset("/content/drive/MyDrive/train.txt", transform=transform)

# %%
from torch.utils.data import DataLoader
from torch.utils.data import random_split, DataLoader
train_size = int(0.8 * len(dataset))
val_size = len(dataset) - train_size
train_dataset, val_dataset = random_split(dataset, [train_size, val_size])

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False)

print(f"Training samples: {len(train_dataset)}")
print(f"Validation samples: {len(val_dataset)}")
# Out:
# Training samples: 298883
# Validation samples: 74721

# %%
test_dataset = ImageDataset("/content/drive/MyDrive/test.txt", transform=transform)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=True)
print(f"Training samples: {len(test_dataset)}")
# Out:
# Training samples: 358955

# %%
for images, labels in train_loader:
    print(images.shape, labels)
    break
# Out:
# torch.Size([32, 3, 224, 224]) tensor([33, 11, 33, 32,  3, 15, 24, 31, 31,  3, 14, 28, 35,  8, 15, 32, 11, 32,
#         35, 32, 14, 11, 32, 15,  5, 34, 15, 35, 32, 24, 15, 15])

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from tqdm import tqdm
import torchvision.models as models

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
model = models.efficientnet_b0(weights=models.EfficientNet_B0_Weights.IMAGENET1K_V1)

num_ftrs = model.classifier[1].in_features
num_classes = 38
model.classifier[1] = nn.Linear(num_ftrs, num_classes)

for param in model.features.parameters():
    param.requires_grad = False
for param in model.classifier.parameters():
    param.requires_grad = True

model = model.to(device)

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.classifier.parameters(), lr=0.0001)
scaler = torch.cuda.amp.GradScaler()


num_epochs = 70
train_acc_history = []
val_acc_history = []

for epoch in range(num_epochs):
    model.train()
    correct = 0
    total = 0
    running_loss = 0.0

    for images, labels in tqdm(train_loader, desc=f"Epoch {epoch+1}/{num_epochs}", leave=False):
        images, labels = images.to(device), labels.to(device)

        optimizer.zero_grad()

        with torch.cuda.amp.autocast():
            outputs = model(images)
            loss = criterion(outputs, labels)

        scaler.scale(loss).backward()
        scaler.step(optimizer)
        scaler.update()

        running_loss += loss.item()
        _, predicted = torch.max(outputs, 1)
        correct += (predicted == labels).sum().item()
        total += labels.size(0)

    train_acc = 100 * correct / total
    train_acc_history.append(train_acc)
    print(f"Epoch {epoch+1}/{num_epochs}, Loss: {running_loss / len(train_loader):.4f}, Accuracy: {train_acc:.2f}%")

torch.save(model.state_dict(), "efficientnet_b0_trained.pth")
print("\nModel saved as efficientnet_b0_trained.pth")
# Out:
# Using device: cuda

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from tqdm import tqdm
import torchvision.models as models

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

model = models.googlenet(weights=models.GoogLeNet_Weights.IMAGENET1K_V1)

num_ftrs = model.fc.in_features
num_classes = 38
model.fc = nn.Linear(num_ftrs, num_classes)

for param in model.parameters():
    param.requires_grad = False
for param in model.fc.parameters():
    param.requires_grad = True

model = model.to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.fc.parameters(), lr=0.0001)
scaler = torch.cuda.amp.GradScaler()

num_epochs = 1
train_acc_history = []
val_acc_history = []
test_acc_history = []

for epoch in range(num_epochs):
    model.train()
    correct = 0
    total = 0
    running_loss = 0.0

    for images, labels in tqdm(train_loader, desc=f"Epoch {epoch+1}/{num_epochs}", leave=False):
        images, labels = images.to(device), labels.to(device)

        optimizer.zero_grad()

        with torch.cuda.amp.autocast():
            outputs = model(images)
            loss = criterion(outputs, labels)

        scaler.scale(loss).backward()
        scaler.step(optimizer)
        scaler.update()

        running_loss += loss.item()
        _, predicted = torch.max(outputs, 1)
        correct += (predicted == labels).sum().item()
        total += labels.size(0)

    train_acc = 100 * correct / total
    print(f"Epoch {epoch+1}/{num_epochs}, Loss: {running_loss / len(train_loader):.4f}, Accuracy: {train_acc:.2f}%")

torch.save(model.state_dict(), "googlenet_trained.pth")
print("\nModel saved as googlenet_trained.pth")
# Out:
# Using device: cuda

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import models, transforms
from torch.utils.data import DataLoader
from tqdm import tqdm

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

model = models.inception_v3(weights=models.Inception_V3_Weights.IMAGENET1K_V1)
num_ftrs = model.fc.in_features
num_classes = 6
model.fc = nn.Linear(num_ftrs, num_classes)

for param in model.parameters():
    param.requires_grad = False
for param in model.fc.parameters():
    param.requires_grad = True

model = model.to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.fc.parameters(), lr=0.0001)
scaler = torch.cuda.amp.GradScaler()


num_epochs = 70
train_acc_history = []

for epoch in range(num_epochs):
    model.train()
    correct = 0
    total = 0
    running_loss = 0.0

    for images, labels in tqdm(train_loader):
        images, labels = images.to(device), labels.to(device)

        optimizer.zero_grad()

        with torch.cuda.amp.autocast():
            outputs = model(images)

            if isinstance(outputs, tuple):
                outputs = outputs[0]

            loss = criterion(outputs, labels)

        scaler.scale(loss).backward()
        scaler.step(optimizer)
        scaler.update()

        running_loss += loss.item()
        _, predicted = torch.max(outputs, 1)
        correct += (predicted == labels).sum().item()
        total += labels.size(0)

    print(f"Epoch {epoch+1}/{num_epochs}, Loss: {running_loss / len(train_loader):.4f}, Accuracy: {100 * correct / total:.2f}%")

torch.save(model.state_dict(), "inception_trained.pth")
print("\nModel saved as inception_trained.pth")

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision.models as models
from tqdm import tqdm
from torch.utils.data import DataLoader

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

model = models.vgg16(weights=models.VGG16_Weights.IMAGENET1K_V1)
num_ftrs = model.classifier[6].in_features
num_classes = 38
model.classifier[6] = nn.Linear(num_ftrs, num_classes)

for param in model.parameters():
    param.requires_grad = False
for param in model.classifier[6].parameters():
    param.requires_grad = True

model = model.to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.classifier[6].parameters(), lr=0.0001)
scaler = torch.amp.GradScaler()

num_epochs = 1
train_acc_history = []
val_acc_history = []
test_acc_history = []

for epoch in range(num_epochs):
    model.train()
    correct = 0
    total = 0
    running_loss = 0.0

    print(f"Epoch {epoch+1}/{num_epochs}")
    with tqdm(train_loader, desc="Training", leave=False) as pbar:
        for images, labels in pbar:
            images, labels = images.to(device), labels.to(device)

            optimizer.zero_grad()

            with torch.amp.autocast(device_type="cuda"):
                outputs = model(images)
                loss = criterion(outputs, labels)

            scaler.scale(loss).backward()
            scaler.step(optimizer)
            scaler.update()

            running_loss += loss.item()
            _, predicted = torch.max(outputs, 1)
            correct += (predicted == labels).sum().item()
            total += labels.size(0)

            pbar.set_postfix({
                "Loss": f"{running_loss / (total // labels.size(0)):.4f}",
                "Acc": f"{100 * correct / total:.2f}%"
            })

    print(f"Epoch {epoch+1} completed. Loss: {running_loss / len(train_loader):.4f}, Accuracy: {100 * correct / total:.2f}%")

torch.save(model.state_dict(), "vggnet_trained.pth")
print("\nModel saved as vggnet_trained.pth")
# Out:
# Using device: cuda
# Epoch 1/1
# Epoch 1 completed. Loss: 0.8084, Accuracy: 77.23%
#
# Model saved as vggnet_trained.pth

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision.models as models
from tqdm import tqdm
from torch.utils.data import DataLoader

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

model = models.alexnet(weights=models.AlexNet_Weights.IMAGENET1K_V1)
num_ftrs = model.classifier[6].in_features
num_classes = 6
model.classifier[6] = nn.Linear(num_ftrs, num_classes)

for param in model.parameters():
    param.requires_grad = False
for param in model.classifier[6].parameters():
    param.requires_grad = True

model = model.to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.classifier[6].parameters(), lr=0.0001)
scaler = torch.amp.GradScaler()

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True, num_workers=4, pin_memory=True)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False, num_workers=4, pin_memory=True)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False, num_workers=4, pin_memory=True)

num_epochs = 70
train_acc_history = []
val_acc_history = []
test_acc_history = []

for epoch in range(num_epochs):
    model.train()
    correct = 0
    total = 0
    running_loss = 0.0

    for images, labels in train_loader:
        images, labels = images.to(device), labels.to(device)

        optimizer.zero_grad()

        with torch.amp.autocast(device_type="cuda"):
            outputs = model(images)
            loss = criterion(outputs, labels)

        scaler.scale(loss).backward()
        scaler.step(optimizer)
        scaler.update()

        running_loss += loss.item()
        _, predicted = torch.max(outputs, 1)
        correct += (predicted == labels).sum().item()
        total += labels.size(0)
    print(f"Loss: {running_loss / len(train_loader):.4f}, Accuracy: {100 * correct / total:.2f}%")

torch.save(model.state_dict(), "alexnet_trained.pth")
print("\n Model saved as alexnet_trained.pth")

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision.models as models
from tqdm import tqdm
from torch.utils.data import DataLoader

# Device configuration
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# Load pre-trained ResNet50 and modify the final layer
model = models.resnet50(weights=models.ResNet50_Weights.IMAGENET1K_V1)
num_ftrs = model.fc.in_features
num_classes = 38
model.fc = nn.Linear(num_ftrs, num_classes)

# Freeze all layers except the last fully connected layer
for param in model.parameters():
    param.requires_grad = False
for param in model.fc.parameters():
    param.requires_grad = True

model = model.to(device)

# Define loss function and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.fc.parameters(), lr=0.0001)
scaler = torch.cuda.amp.GradScaler()

train_loader = DataLoader(
    train_dataset, batch_size=32, shuffle=True, num_workers=4, pin_memory=True
)
val_loader = DataLoader(
    val_dataset, batch_size=32, shuffle=False, num_workers=4, pin_memory=True
)
test_loader = DataLoader(
    test_dataset, batch_size=32, shuffle=False, num_workers=4, pin_memory=True
)

num_epochs = 6
train_acc_history = []

for epoch in range(num_epochs):
    model.train()
    correct = 0
    total = 0
    running_loss = 0.0

    loop = tqdm(train_loader, leave=True, desc=f"Epoch [{epoch+1}/{num_epochs}]")

    for images, labels in loop:
        images, labels = images.to(device), labels.to(device)

        optimizer.zero_grad()

        with torch.cuda.amp.autocast():
            outputs = model(images)
            loss = criterion(outputs, labels)

        scaler.scale(loss).backward()
        scaler.step(optimizer)
        scaler.update()

        running_loss += loss.item()
        _, predicted = torch.max(outputs, 1)
        correct += (predicted == labels).sum().item()
        total += labels.size(0)

        loop.set_postfix(
            loss=running_loss / (total / labels.size(0)), accuracy=100 * correct / total
        )

    print(
        f"Epoch {epoch+1}/{num_epochs}, Loss: {running_loss / len(train_loader):.4f}, Accuracy: {100 * correct / total:.2f}%"
    )

torch.save(model.state_dict(), "resnet_trained.pth")
print("\nModel saved as resnet_trained.pth")

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from tqdm import tqdm
import torchvision.models as models

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

model = models.vit_b_16(weights=models.ViT_B_16_Weights.IMAGENET1K_V1)
num_ftrs = model.heads.head.in_features
num_classes = 38
model.heads.head = nn.Linear(num_ftrs, num_classes)

for param in model.encoder.parameters():
    param.requires_grad = False

for param in model.heads.parameters():
    param.requires_grad = True

model = model.to(device)

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.heads.parameters(), lr=0.0001)
scaler = torch.cuda.amp.GradScaler()

num_epochs = 1
train_acc_history = []

for epoch in range(num_epochs):
    model.train()
    correct = 0
    total = 0
    running_loss = 0.0

    for images, labels in tqdm(
        train_loader, desc=f"Epoch {epoch+1}/{num_epochs}", leave=False
    ):
        images, labels = images.to(device), labels.to(device)
        optimizer.zero_grad()

        with torch.cuda.amp.autocast():
            outputs = model(images)
            loss = criterion(outputs, labels)

        scaler.scale(loss).backward()
        scaler.step(optimizer)
        scaler.update()

        running_loss += loss.item()
        _, predicted = torch.max(outputs, 1)
        correct += (predicted == labels).sum().item()
        total += labels.size(0)

    train_acc = 100 * correct / total
    train_acc_history.append(train_acc)
    print(
        f"Epoch {epoch+1}/{num_epochs}, Loss: {running_loss / len(train_loader):.4f}, Accuracy: {train_acc:.2f}%"
    )

torch.save(model.state_dict(), "vit_b_16_trained.pth")
print("\nModel saved as vit_b_16_trained.pth")

# %%
class_map = {
    0: "Apple___Apple_scab",
    1: "Apple___Black_rot",
    2: "Apple___Cedar_apple_rust",
    3: "Apple___healthy",
    4: "Blueberry___healthy",
    5: "Cherry_(including_sour)___Powdery_mildew",
    6: "Cherry_(including_sour)___healthy",
    7: "Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot",
    8: "Corn_(maize)___Common_rust_",
    9: "Corn_(maize)___Northern_Leaf_Blight",
    10: "Corn_(maize)___healthy",
    11: "Grape___Black_rot",
    12: "Grape___Esca_(Black_Measles)",
    13: "Grape___Leaf_blight_(Isariopsis_Leaf_Spot)",
    14: "Grape___healthy",
    15: "Orange___Haunglongbing_(Citrus_greening)",
    16: "Peach___Bacterial_spot",
    17: "Peach___healthy",
    18: "Pepper,_bell___Bacterial_spot",
    19: "Pepper,_bell___healthy",
    20: "Potato___Early_blight",
    21: "Potato___Late_blight",
    22: "Potato___healthy",
    23: "Raspberry___healthy",
    24: "Soybean___healthy",
    25: "Squash___Powdery_mildew",
    26: "Strawberry___Leaf_scorch",
    27: "Strawberry___healthy",
    28: "Tomato___Bacterial_spot",
    29: "Tomato___Early_blight",
    30: "Tomato___Late_blight",
    31: "Tomato___Leaf_Mold",
    32: "Tomato___Septoria_leaf_spot",
    33: "Tomato___Spider_mites Two-spotted_spider_mite",
    34: "Tomato___Target_Spot",
    35: "Tomato___Tomato_Yellow_Leaf_Curl_Virus",
    36: "Tomato___Tomato_mosaic_virus",
    37: "Tomato___healthy"
}

# %%
checkpoint = torch.load("/content/efficientnet_b0_trained.pth")
model.load_state_dict(checkpoint)
# Out:
# <ipython-input-25-9414d68aa1a3>:1: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load("/content/efficientnet_b0_trained.pth")
# <All keys matched successfully>

# %%
import numpy as np
import torch
from tqdm import tqdm

class_names = class_map
num_classes = len(class_names)
def calculate_per_class_accuracy(model, data_loaders, device, datasets=[ "Validation", "Test"]):
    for dataset_type, data_loader in zip(datasets, data_loaders):
        model.eval()
        class_correct = np.zeros(num_classes)
        class_total = np.zeros(num_classes)

        print(f"\nCalculating Per-Class {dataset_type} Accuracy...")
        with torch.no_grad():
            for steps , (images, labels) in tqdm(enumerate(data_loader), desc=f"{dataset_type} Progress", leave=True):
                if steps == 2000:
                  break
                images, labels = images.to(device), labels.to(device)
                outputs = model(images)
                _, predicted = torch.max(outputs, 1)

                for i in range(len(labels)):
                    label = labels[i].item()
                    class_correct[label] += (predicted[i] == label).item()
                    class_total[label] += 1

        print(f"\nFinal Per-Class {dataset_type} Accuracy:\n")
        for i in range(num_classes):
            if class_total[i] > 0:
                accuracy = 100 * class_correct[i] / class_total[i]
                print(f"{class_names[i]}: {dataset_type} Accuracy = {accuracy:.2f}%")
            else:
                print(f"{class_names[i]}: {dataset_type} Accuracy = No samples available")

data_loaders = [val_loader, test_loader]
datasets = [ "Validation", "Test"]
calculate_per_class_accuracy(model, data_loaders, device, datasets=datasets)
# Out:
# Calculating Per-Class Validation Accuracy...
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:617: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# Validation Progress: 2000it [03:09, 10.58it/s]
# Final Per-Class Validation Accuracy:
#
# Apple___Apple_scab: Validation Accuracy = 76.70%
# Apple___Black_rot: Validation Accuracy = 95.08%
# Apple___Cedar_apple_rust: Validation Accuracy = 88.34%
# Apple___healthy: Validation Accuracy = 92.18%
# Blueberry___healthy: Validation Accuracy = 97.27%
# Cherry_(including_sour)___Powdery_mildew: Validation Accuracy = 93.28%
# Cherry_(including_sour)___healthy: Validation Accuracy = 98.47%
# Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot: Validation Accuracy = 72.24%
# Corn_(maize)___Common_rust_: Validation Accuracy = 99.30%
# Corn_(maize)___Northern_Leaf_Blight: Validation Accuracy = 88.51%
# Corn_(maize)___healthy: Validation Accuracy = 99.64%
# Grape___Black_rot: Validation Accuracy = 88.72%
# Grape___Esca_(Black_Measles): Validation Accuracy = 94.43%
# Grape___Leaf_blight_(Isariopsis_Leaf_Spot): Validation Accuracy = 96.55%
# Grape___healthy: Validation Accuracy = 96.60%
# Orange___Haunglongbing_(Citrus_greening): Validation Accuracy = 99.47%
# Peach___Bacterial_spot: Validation Accuracy = 94.48%
# Peach___healthy: Validation Accuracy = 92.71%
# Pepper,_bell___Bacterial_spot: Validation Accuracy = 89.57%
# Pepper,_bell___healthy: Validation Accuracy = 94.74%
# Potato___Early_blight: Validation Accuracy = 93.45%
# Potato___Late_blight: Validation Accuracy = 83.63%
# Potato___healthy: Validation Accuracy = 71.57%
# Raspberry___healthy: Validation Accuracy = 97.51%
# Soybean___healthy: Validation Accuracy = 98.83%
# Squash___Powdery_mildew: Validation Accuracy = 99.28%
# Strawberry___Leaf_scorch: Validation Accuracy = 97.30%
# Strawberry___healthy: Validation Accuracy = 93.10%
# Tomato___Bacterial_spot: Validation Accuracy = 88.69%
# Tomato___Early_blight: Validation Accuracy = 48.30%
# Tomato___Late_blight: Validation Accuracy = 79.35%
# Tomato___Leaf_Mold: Validation Accuracy = 73.76%
# Tomato___Septoria_leaf_spot: Validation Accuracy = 77.68%
# Tomato___Spider_mites Two-spotted_spider_mite: Validation Accuracy = 86.04%
# Tomato___Target_Spot: Validation Accuracy = 76.24%
# Tomato___Tomato_Yellow_Leaf_Curl_Virus: Validation Accuracy = 95.50%
# Tomato___Tomato_mosaic_virus: Validation Accuracy = 78.35%
# Tomato___healthy: Validation Accuracy = 95.35%
#
# Calculating Per-Class Test Accuracy...
# Test Progress: 2000it [03:06, 10.71it/s]
# Final Per-Class Test Accuracy:
#
# Apple___Apple_scab: Test Accuracy = 85.51%
# Apple___Black_rot: Test Accuracy = 97.29%
# Apple___Cedar_apple_rust: Test Accuracy = 92.06%
# Apple___healthy: Test Accuracy = 94.90%
# Blueberry___healthy: Test Accuracy = 99.18%
# Cherry_(including_sour)___Powdery_mildew: Test Accuracy = 96.52%
# Cherry_(including_sour)___healthy: Test Accuracy = 98.38%
# Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot: Test Accuracy = 75.94%
# Corn_(maize)___Common_rust_: Test Accuracy = 98.19%
# Corn_(maize)___Northern_Leaf_Blight: Test Accuracy = 84.11%
# Corn_(maize)___healthy: Test Accuracy = 99.61%
# Grape___Black_rot: Test Accuracy = 95.07%
# Grape___Esca_(Black_Measles): Test Accuracy = 96.84%
# Grape___Leaf_blight_(Isariopsis_Leaf_Spot): Test Accuracy = 97.32%
# Grape___healthy: Test Accuracy = 97.97%
# Orange___Haunglongbing_(Citrus_greening): Test Accuracy = 99.53%
# Peach___Bacterial_spot: Test Accuracy = 95.52%
# Peach___healthy: Test Accuracy = 96.68%
# Pepper,_bell___Bacterial_spot: Test Accuracy = 87.78%
# Pepper,_bell___healthy: Test Accuracy = 96.61%
# Potato___Early_blight: Test Accuracy = 97.29%
# Potato___Late_blight: Test Accuracy = 87.63%
# Potato___healthy: Test Accuracy = 78.79%
# Raspberry___healthy: Test Accuracy = 99.61%
# Soybean___healthy: Test Accuracy = 98.57%
# Squash___Powdery_mildew: Test Accuracy = 99.65%
# Strawberry___Leaf_scorch: Test Accuracy = 99.06%
# Strawberry___healthy: Test Accuracy = 99.52%
# Tomato___Bacterial_spot: Test Accuracy = 85.24%
# Tomato___Early_blight: Test Accuracy = 55.47%
# Tomato___Late_blight: Test Accuracy = 84.94%
# Tomato___Leaf_Mold: Test Accuracy = 76.68%
# Tomato___Septoria_leaf_spot: Test Accuracy = 85.71%
# Tomato___Spider_mites Two-spotted_spider_mite: Test Accuracy = 87.53%
# Tomato___Target_Spot: Test Accuracy = 79.38%
# Tomato___Tomato_Yellow_Leaf_Curl_Virus: Test Accuracy = 95.05%
# Tomato___Tomato_mosaic_virus: Test Accuracy = 88.79%
# Tomato___healthy: Test Accuracy = 94.41%

# %%
import numpy as np
import torch
from sklearn.metrics import precision_recall_curve, average_precision_score
import matplotlib.pyplot as plt
from tqdm import tqdm

y_true = []
y_scores = []
model.eval()

correct = 0
total = 0

with torch.no_grad():
    for steps, (images, labels) in enumerate(tqdm(test_loader, desc="Calculating Test Accuracy", total=2000)):
        if steps == 1000:
            break
        images, labels = images.to(device), labels.to(device)
        outputs = model(images)
        _, predicted = torch.max(outputs, 1)
        correct += (predicted == labels).sum().item()
        total += labels.size(0)

test_acc = 100 * correct / total
print(f"Test Accuracy: {test_acc:.2f}%")

with torch.no_grad():
    for steps, (images, labels) in enumerate(tqdm(test_loader, desc="Calculating Precision-Recall Data", total=2000)):
        if steps == 1000:
            break
        images, labels = images.to(device), labels.to(device)
        outputs = model(images)
        probs = torch.nn.functional.softmax(outputs, dim=1)

        y_true.extend(labels.cpu().numpy())
        y_scores.extend(probs.cpu().numpy())

y_true = np.array(y_true)
y_scores = np.array(y_scores)

plt.figure(figsize=(10, 5))
for i in range(len(class_names)):
    precision, recall, _ = precision_recall_curve(y_true == i, y_scores[:, i])
    avg_precision = average_precision_score(y_true == i, y_scores[:, i])
    plt.plot(recall, precision, label=f"{class_names[i]} (AP={avg_precision:.2f})")

plt.xlabel("Recall")
plt.ylabel("Precision")
plt.title("Precision-Recall Curve for Plant Disease Classification")
plt.legend()
plt.show()
# Out:
# Calculating Test Accuracy:  50%|█████     | 1000/2000 [01:33<01:33, 10.75it/s]
# Test Accuracy: 93.00%
# Calculating Precision-Recall Data:  50%|█████     | 1000/2000 [01:32<01:32, 10.80it/s]
